# %%
# spliting train and val
from random import sample
total = []
for i in range(1,300):
    total.append("/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_" + str(i) + ".jpg")
val = sample(total,60)
train = list(set(total) - set(val))

# %%
val
# Out:
# ['/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_235.jpg',
#  '/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_116.jpg',
#  '/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_208.jpg',
#  '/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_30.jpg',
#  '/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_244.jpg',
#  '/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_91.jpg',
#  '/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_165.jpg',
#  '/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_14.jpg',
#  '/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_203.jpg',
#  '/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_4.jpg',
#  '/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_163.jpg',
# ...

# %%
train
# Out:
# ['/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_19.jpg',
#  '/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_176.jpg',
#  '/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_289.jpg',
#  '/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_109.jpg',
#  '/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_26.jpg',
#  '/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_95.jpg',
#  '/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_130.jpg',
#  '/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_29.jpg',
#  '/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_36.jpg',
#  '/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_1.jpg',
#  '/home/zz2496/Notebooks/CSRNet/shanghai/part_A_final/train_data/images/IMG_56.jpg',
# ...
